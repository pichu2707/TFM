# %%
import pandas as pd

# %%
conexoo_df = pd.read_csv('conexoo.csv')
publisuites_df = pd.read_csv('publisuites.csv')
prensarank_df = pd.read_csv('prensarank.csv')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'id', 'url', 'CF', 'DA', 'DR', 'IV', 'OBL', 'PA', 'RD',
#        'TF', 'Tráfico web/mes', 'pais', 'patrocinado', 'price', 'region',
#        'tipoMedio', 'langsselect', 'categoriesselect'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'url', 'urls_site', 'dr', 'da', 'cf', 'tf',
#        'obl', 'dom', 'traffic', 'price', 'pa', 'max_links', 'max_links_groups',
#        'lang_filter', 'category_filter', 'create_groups', 'ip', 'promoted',
#        'offer', 'in_front_page', 'is_new', 'created_at', 'status', 'TrType',
#        'type'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'id', 'url', 'url_link', 'descripcion', 'idioma',
#        'idioma_traducido', 'pais_audiencia', 'da', 'cf', 'dr', 'pa', 'ur',
#        'tf', 'rd', 'obl', 'precio_post', 'precio_post_cliente',
#        'max_links_post', 'tipo_sitio', 'tipo_sitio_text', 'crank', 'keywords',
#        'traffic_organic', 'majestic_links', 'majestic_rd', 'art_ya_pub',
#        'aviso_publicidad', 'bl', 'clase_web', 'clase_web_text', 'created_at',
#        'discard', 'favorite', 'group_check', 'home_appearance', 'image',
#        'newsletter_difusion', 'ps_rank', 'social_publication',
#        'tarjetas_rojas', 'texto_conexoo', 'updated_at', 'userId',
#        'valoraciones_count', 'visitas_dia', 'categorias_agregadas_arr',
#        'tematicas_no_aceptadas_arr'],
#       dtype='object')

# %%
df3 = df3.rename(columns={'piece':'price'})
df3.columns
# Out:
# Index(['Unnamed: 0', 'id', 'url', 'url_link', 'descripcion', 'idioma',
#        'idioma_traducido', 'pais_audiencia', 'da', 'cf', 'dr', 'pa', 'ur',
#        'tf', 'rd', 'obl', 'price', 'precio_post_cliente', 'max_links_post',
#        'tipo_sitio', 'tipo_sitio_text', 'crank', 'keywords', 'traffic_organic',
#        'majestic_links', 'majestic_rd', 'art_ya_pub', 'aviso_publicidad', 'bl',
#        'clase_web', 'clase_web_text', 'created_at', 'discard', 'favorite',
#        'group_check', 'home_appearance', 'image', 'newsletter_difusion',
#        'ps_rank', 'social_publication', 'tarjetas_rojas', 'texto_conexoo',
#        'updated_at', 'userId', 'valoraciones_count', 'visitas_dia',
#        'categorias_agregadas_arr', 'tematicas_no_aceptadas_arr'],
#       dtype='object')

# %%
merged_df = conexoo_df.merge(publisuites_df, on='url', how='outer', suffixes=('_conexoo', '_publisuites'))
merged_df = merged_df.merge(prensarank_df, on='url', how='outer')
merged_df
# Out:
#        Unnamed: 0_conexoo  id_conexoo                                url  \
# 0                     0.0       771.0  https://www.marketingdirecto.com/
# 1                   733.0       771.0  https://www.marketingdirecto.com/
# 2                     1.0      1665.0     https://www.lavozdegalicia.es/
# 3                   728.0      1665.0     https://www.lavozdegalicia.es/
# 4                     2.0       538.0       https://www.larepublica.net/
# ...                   ...         ...                                ...
# 17339                 NaN         NaN               https://junin24.com/
# 17340                 NaN         NaN               https://junin24.com/
# 17341                 NaN         NaN               https://junin24.com/
# 17342                 NaN         NaN               https://junin24.com/
# 17343                 NaN         NaN               https://junin24.com/
#
#                                                 url_link  \
# ...

# %%
def highlight_lowest_price(row):
    return ['background-color: yellow' if x == row.min() else '' for x in row]

styled_df = merged_df.style.apply(highlight_lowest_price, axis=1)
styled_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/style.py:205, in Styler._repr_html_(self)
#     201 def _repr_html_(self) -> str:
#     202     """
#     203     Hooks into Jupyter notebook rich display system.
#     204     """
# --> 205     return self.render()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/style.py:619, in Styler.render(self, **kwargs)
#     581 def render(self, **kwargs) -> str:
#     582     """
#     583     Render the built up styles to HTML.
#     584
#    (...)
# ...

# %%
styled_df = styled_df.set_properties(**{'text-align': 'right'})
styled_df.set_precision(2)
styled_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py:343, in BaseFormatter.__call__(self, obj)
#     341     method = get_real_method(obj, self.print_method)
#     342     if method is not None:
# --> 343         return method()
#     344     return None
#     345 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/style.py:205, in Styler._repr_html_(self)
#     201 def _repr_html_(self) -> str:
#     202     """
#     203     Hooks into Jupyter notebook rich display system.
#     204     """
# --> 205     return self.render()
#
# File ~/.local/lib/python3.10/site-packages/pandas/io/formats/style.py:619, in Styler.render(self, **kwargs)
#     581 def render(self, **kwargs) -> str:
#     582     """
#     583     Render the built up styles to HTML.
#     584
#    (...)
# ...
